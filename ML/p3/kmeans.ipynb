# %%
from sklearn.cluster import KMeans
import numpy as np
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
data = load_iris()
iris = data.data
petal_len = iris
print(petal_len)
k_means = KMeans(n_clusters=3) #三个聚类中心
result = k_means.fit(petal_len) #Kmeans自动分类
kc = result.cluster_centers_ #自动分类后的聚类中心
y_means = k_means.predict(petal_len) #预测Y值
plt.scatter(petal_len[:,0],petal_len[:,2],c=y_means, marker='*', label='see')
plt.show()
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter 
data = pd.read_csv("TrainSamples.csv",header=None).values
label = pd.read_csv("TrainLabels.csv",header=None).values.ravel()
mnist = data
k_means = KMeans(n_clusters=10)
result = k_means.fit(mnist)    #Kmeans自动分类
kc = result.cluster_centers_   #自动分类后的聚类中心
y = k_means.predict(mnist)

# %%
y
# Out:
# array([7, 4, 8, ..., 2, 9, 3])

# %%
label
# Out:
# array([5, 0, 4, ..., 6, 7, 1], dtype=int64)

# %%
A = []
for k in range(10):
    A.append([label[i]  for i in range(30000) if y[i] == k])
    print(f"第{k}类：{len(A[k])}个")
    print(Counter(A[k]))
# Out:
# 第0类：3967个
# Counter({3: 1969, 5: 891, 8: 715, 2: 201, 0: 122, 9: 47, 6: 17, 1: 4, 7: 1})
# 第1类：3247个
# Counter({7: 1388, 9: 846, 4: 752, 5: 108, 8: 100, 2: 28, 3: 17, 0: 5, 1: 3})
# 第2类：2722个
# Counter({6: 2327, 0: 110, 2: 89, 5: 70, 4: 56, 8: 35, 3: 23, 1: 6, 9: 4, 7: 2})
# 第3类：2640个
# Counter({1: 1579, 5: 301, 2: 187, 8: 171, 7: 122, 4: 109, 6: 83, 3: 47, 9: 35, 0: 6})
# 第4类：2461个
# Counter({0: 2303, 6: 42, 5: 36, 2: 26, 3: 16, 8: 16, 9: 15, 7: 4, 4: 3})
# 第5类：2859个
# Counter({1: 1814, 3: 231, 8: 174, 2: 171, 6: 140, 7: 105, 5: 99, 9: 72, 4: 53})
# 第6类：2233个
# Counter({2: 2031, 3: 103, 6: 29, 7: 18, 8: 17, 0: 10, 4: 9, 5: 6, 1: 6, 9: 4})
# 第7类：3491个
# Counter({8: 1456, 5: 935, 3: 558, 0: 341, 2: 85, 6: 81, 9: 21, 4: 7, 1: 6, 7: 1})
# 第8类：2800个
# Counter({4: 1133, 9: 750, 7: 300, 6: 255, 2: 114, 5: 86, 8: 68, 0: 56, 3: 36, 1: 2})
# 第9类：3580个
# Counter({9: 1209, 7: 1166, 4: 804, 5: 177, 8: 123, 3: 73, 2: 16, 0: 8, 1: 3, 6: 1})

# %%
B = []
for k in range(10):
    B.append([y[i] for i in range(30000) if label[i] == k])
    print(f"数字{k}：{len(B[k])}个")
    print(Counter(B[k]))
# Out:
# 数字0：2961个
# Counter({4: 2303, 7: 341, 0: 122, 2: 110, 8: 56, 6: 10, 9: 8, 3: 6, 1: 5})
# 数字1：3423个
# Counter({5: 1814, 3: 1579, 7: 6, 6: 6, 2: 6, 0: 4, 9: 3, 1: 3, 8: 2})
# 数字2：2948个
# Counter({6: 2031, 0: 201, 3: 187, 5: 171, 8: 114, 2: 89, 7: 85, 1: 28, 4: 26, 9: 16})
# 数字3：3073个
# Counter({0: 1969, 7: 558, 5: 231, 6: 103, 9: 73, 3: 47, 8: 36, 2: 23, 1: 17, 4: 16})
# 数字4：2926个
# Counter({8: 1133, 9: 804, 1: 752, 3: 109, 2: 56, 5: 53, 6: 9, 7: 7, 4: 3})
# 数字5：2709个
# Counter({7: 935, 0: 891, 3: 301, 9: 177, 1: 108, 5: 99, 8: 86, 2: 70, 4: 36, 6: 6})
# 数字6：2975个
# Counter({2: 2327, 8: 255, 5: 140, 3: 83, 7: 81, 4: 42, 6: 29, 0: 17, 9: 1})
# 数字7：3107个
# Counter({1: 1388, 9: 1166, 8: 300, 3: 122, 5: 105, 6: 18, 4: 4, 2: 2, 7: 1, 0: 1})
# 数字8：2875个
# Counter({7: 1456, 0: 715, 5: 174, 3: 171, 9: 123, 1: 100, 8: 68, 2: 35, 6: 17, 4: 16})
# 数字9：3003个
# Counter({9: 1209, 1: 846, 8: 750, 5: 72, 0: 47, 3: 35, 7: 21, 4: 15, 2: 4, 6: 4})

# %%
r1 = [mnist[i] for i in range(30000) if label[i] == 3]
r2 = [mnist[i] for i in range(30000) if label[i] == 5]
len1 = len(r1)
len2 = len(r2)
R = r1+r2

k_means_2 = KMeans(n_clusters=2)
result2 = k_means_2.fit(mnist)    #Kmeans自动分类
kc2 = result2.cluster_centers_   #自动分类后的聚类中心
y2 = k_means_2.predict(mnist)

print(f"数字3: {len1}个 ",Counter(y2[0:len1]))
print(f"数字5：{len2}个 ",Counter(y2[len1:len1+len2]))
# Out:
# 数字3: 3073个  Counter({0: 1932, 1: 1141})
# 数字5：2709个  Counter({0: 1650, 1: 1059})

# %%
r1 = [mnist[i] for i in range(30000) if label[i] == 0]
r2 = [mnist[i] for i in range(30000) if label[i] == 2]
len1 = len(r1)
len2 = len(r2)
R = r1+r2

k_means_2 = KMeans(n_clusters=2)
result2 = k_means_2.fit(mnist)    #Kmeans自动分类
kc2 = result2.cluster_centers_   #自动分类后的聚类中心
y2 = k_means_2.predict(mnist)

print(f"数字0: {len1}个 ",Counter(y2[0:len1]))
print(f"数字2：{len2}个 ",Counter(y2[len1:len1+len2]))
# Out:
# 数字0: 2961个  Counter({0: 1862, 1: 1099})
# 数字2：2948个  Counter({0: 1806, 1: 1142})

# %%
y2
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %%
print(len1,len2)
# Out:
# 3073 2709
