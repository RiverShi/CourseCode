# %%
import matplotlib.pyplot as plt
from ctypes import *
import math
import os

# %%
Fib = cdll.LoadLibrary("./Fib_wsl.so")

# %%
Fib.get_timeof_DT(10000000)
# Out:
# 21463

# %%
a = range(1,46)
b = list(map(Fib.get_timeof_DG, a))
plt.plot(a,b)

# %%
f = open("DG.txt",'w',encoding="UTF-8")
for i in range(0,44):
    print(f"{a[i]}\t{b[i]}",file=f)
f.close()

# %%
a = range(1,100001)
b = list(map(Fib.get_timeof_DT, a))
plt.plot(a,b)

# %%
f = open("DT.txt",'w',encoding="UTF-8")
for i in range(0,100000):
    print(f"{a[i]}\t{b[i]}",file=f)
f.close()

# %%
a = range(1,100000+1)
b = list(map(Fib.get_timeof_DP, a))
plt.plot(a,b)

# %%
f = open("DP.txt",'w',encoding="UTF-8")
for i in range(0,100000):
    print(f"{a[i]}\t{b[i]}",file=f)
f.close()

# %%
a = range(1,100000+1)
b = list(map(Fib.get_timeof_GF, a))
plt.plot(a,b)

# %%
f = open("GF.txt",'w',encoding="UTF-8")
for i in range(0,100000):
    print(f"{a[i]}\t{b[i]}",file=f)
f.close()

# %%
a = range(1,100000+1)
b = list(map(Fib.get_timeof_Matrix, a))
plt.plot(a,b)

# %%
f = open("Matrix.txt",'w',encoding="UTF-8")
for i in range(0,100000):
    print(f"{a[i]}\t{b[i]}",file=f)
f.close()

# %%
Fib.close()
# Out:
# -1

# %%
Fib.get_timeof_DT(100000000)
# Out:
# 213997

# %%
Fib.get_timeof_Matrix(100000000)
# Out:
# 51

# %%
Fib.get_timeof_GF(100000000)
# Out:
# 3
